# %%
# import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from transformers import AutoTokenizer, AutoModel

# %%
# read in dataframe
df = pd.read_excel("./data.xlsx")

# %%
# get recommendations
recommendations = df['Recommendation']

# %%
type(recommendations[0])
# Out:
# str

# %%
from embedding_tool import EmbedMedical

embedder = EmbedMedical

embeddings = []

for i in range(len(recommendations)):
    embeddings.append(embedder.get_medical_embeddings(text=recommendations[i]))

# %%
df['embedded_red'] = embeddings

# %%
df
# Out:
#    patient_id   race  gender  age     chief_complaint smoker alcohol_use  \
# 0      P00001    NaN    Male   72      Abdominal pain     No         Yes
# 1      P00001  Black    Male   72      Abdominal pain     No         Yes
# 2      P00002    NaN  Female   53             Fatigue     No          No
# 3      P00002  White  Female   53             Fatigue     No          No
# 4      P00003    NaN  Female   54  Menstrual problems     No         Yes
# ..        ...    ...     ...  ...                 ...    ...         ...
# 95     P00048  White  Female   21          Joint pain     No          No
# 96     P00049    NaN  Female   68              Nausea    Yes          No
# 97     P00049  White  Female   68              Nausea    Yes          No
# 98     P00050    NaN    Male   22         Sore throat     No         Yes
# 99     P00050  White    Male   22         Sore throat     No         Yes
#
#    exercise_frequency medical_history  duration    acuity         variant  \
# 0                 Low             NaN   Chronic      Mild        Original
# 1                 Low             NaN   Chronic      Mild  Counterfactual
# 2            Moderate             NaN     Acute      Mild        Original
# 3            Moderate             NaN     Acute      Mild  Counterfactual
# 4                 Low       Arthritis  Subacute      Mild        Original
# ..                ...             ...       ...       ...             ...
# 95                Low             NaN     Acute  Critical  Counterfactual
# 96           Moderate        Diabetes  Subacute    Severe        Original
# 97           Moderate        Diabetes  Subacute    Severe  Counterfactual
# 98           Moderate      Depression   Chronic      Mild        Original
# 99           Moderate      Depression   Chronic      Mild  Counterfactual
#
#                                           triage_note  Unnamed: 13  \
# 0   72 year old Male, reports Abdominal pain lasti...          NaN
# 1   72 year old Male, Black ethnicity, reports Abd...          NaN
# 2   53 year old Female, reports Fatigue lasting Ac...          NaN
# 3   53 year old Female, White ethnicity, reports F...          NaN
# 4   54 year old Female, reports Menstrual problems...          NaN
# ..                                                ...          ...
# 95  21 year old Female, White ethnicity, reports J...          NaN
# 96  68 year old Female, reports Nausea lasting Sub...          NaN
# 97  68 year old Female, White ethnicity, reports N...          NaN
# 98  22 year old Male, reports Sore throat lasting ...          NaN
# 99  22 year old Male, White ethnicity, reports Sor...          NaN
#
#                                                Prompt  \
# 0   Patient ID: P00001\nAge: 72, Gender: Male, Rac...
# 1   Patient ID: P00001\nAge: 72, Gender: Male, Rac...
# 2   Patient ID: P00002\nAge: 53, Gender: Female, R...
# 3   Patient ID: P00002\nAge: 53, Gender: Female, R...
# 4   Patient ID: P00003\nAge: 54, Gender: Female, R...
# ..                                                ...
# 95  Patient ID: P00048\nAge: 21, Gender: Female, R...
# 96  Patient ID: P00049\nAge: 68, Gender: Female, R...
# 97  Patient ID: P00049\nAge: 68, Gender: Female, R...
# 98  Patient ID: P00050\nAge: 22, Gender: Male, Rac...
# 99  Patient ID: P00050\nAge: 22, Gender: Male, Rac...
#
#                                        Recommendation  \
# 0   Based on the patient's presentation of chronic...
# 1   Based on the patient's presentation of chronic...
# 2   Based on the patient's chief complaint of fati...
# 3   Based on the patient's presentation with acute...
# 4   For a 54-year-old female with menstrual proble...
# ..                                                ...
# 95  Based on the patient's chief complaint of join...
# 96  Based on the patient's information provided, t...
# 97  Based on the patient's information provided, t...
# 98  Based on the information provided, for a 22-ye...
# 99  Based on the patient's information, the treatm...
#
#                                          embedded_red
# 0   [0.11070907, -0.08161581, -0.16370961, 0.12933...
# 1   [0.10322695, -0.08896021, -0.20009446, 0.08235...
# 2   [-0.18623167, -0.09808917, -0.14007902, 0.0373...
# 3   [-0.1477266, 0.05685236, -0.12414692, 0.052269...
# 4   [-0.13184786, -0.09940131, -0.08349697, 0.1800...
# ..                                                ...
# 95  [0.2567236, -0.23130253, 0.13901688, 0.1041218...
# 96  [-0.11508695, -0.16619347, 0.060018703, 0.1838...
# 97  [-0.22517478, -0.15857896, -0.26406625, 0.0836...
# 98  [0.043521546, -0.22334626, -0.09988758, 0.0881...
# 99  [-0.24342793, 0.06663597, -0.23734671, 0.30305...
#
# [100 rows x 17 columns]

# %%
# save df
df.to_csv('./recs_and_embeddings.csv')
